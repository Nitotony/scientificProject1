# %%
import pandas as pd
import xgboost as xgb
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report, confusion_matrix, precision_score, recall_score, f1_score

from sklearn.model_selection import RandomizedSearchCV

from sklearn.model_selection import GridSearchCV

import numpy as np

from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import SMOTE
from collections import Counter





from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
data=pd.read_csv('../Data/Data.csv')
label=pd.read_csv('../Data/Label.csv')

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(data, label['Label'], test_size=0.2, random_state=42)

# %%
print(X_train.describe(), X_test.describe(), y_train.describe(), y_test.describe())
# Out:
#        Flow Duration  Total Fwd Packet  Total Bwd packets  \
# count   3.583320e+05     358332.000000      358332.000000
# mean    5.965464e+05         22.586163          27.156129
# std     4.880156e+06        128.750057         114.994688
# min     1.000000e+00          1.000000           0.000000
# 25%     3.490000e+02          1.000000           2.000000
# 50%     5.779500e+03          3.000000           2.000000
# 75%     1.780708e+05         17.000000          15.000000
# max     1.199975e+08      19616.000000       11021.000000
#
#        Total Length of Fwd Packet  Total Length of Bwd Packet  \
# count                3.583320e+05                3.583320e+05
# mean                 4.798193e+03                2.159995e+04
# std                  1.529527e+05                1.455858e+05
# min                  0.000000e+00                0.000000e+00
# 25%                  0.000000e+00                0.000000e+00
# 50%                  9.000000e+01                1.060000e+02
# 75%                  4.860000e+02                1.512000e+03
# max                  2.542784e+07                1.421599e+07
#
#        Fwd Packet Length Max  Fwd Packet Length Min  Fwd Packet Length Mean  \
# count          358332.000000          358332.000000           358332.000000
# mean              174.307017              14.959680               71.250855
# std               352.280744              71.797571              184.450945
# min                 0.000000               0.000000                0.000000
# 25%                 0.000000               0.000000                0.000000
# 50%                45.000000               0.000000                9.346154
# 75%               163.000000               0.000000               50.000000
# max              1476.000000            1472.000000             1474.000000
#
#        Fwd Packet Length Std  Bwd Packet Length Max  ...  Fwd Act Data Pkts  \
# count          358332.000000          358332.000000  ...      358332.000000
# mean               63.991340             364.765980  ...           8.641601
# std               156.371702             555.659716  ...         119.561208
# min                 0.000000               0.000000  ...           0.000000
# 25%                 0.000000               0.000000  ...           0.000000
# 50%                 0.000000              48.000000  ...           1.000000
# 75%                28.716733             729.000000  ...          10.000000
# max               848.528137            1460.000000  ...       19612.000000
#
#        Fwd Seg Size Min   Active Mean    Active Std    Active Max  \
# count     358332.000000  3.583320e+05  3.583320e+05  3.583320e+05
# mean          25.918522  1.890836e+04  9.702651e+03  3.198785e+04
# std            9.024148  7.522997e+05  5.348194e+05  1.196326e+06
# min            8.000000  0.000000e+00  0.000000e+00  0.000000e+00
# 25%           20.000000  0.000000e+00  0.000000e+00  0.000000e+00
# 50%           32.000000  0.000000e+00  0.000000e+00  0.000000e+00
# 75%           32.000000  0.000000e+00  0.000000e+00  0.000000e+00
# max           36.000000  1.104063e+08  7.417760e+07  1.104063e+08
#
#          Active Min     Idle Mean      Idle Std      Idle Max      Idle Min
# count  3.583320e+05  3.583320e+05  3.583320e+05  3.583320e+05  3.583320e+05
# mean   1.257963e+04  9.846746e+04  3.172545e+03  1.024053e+05  9.580520e+04
# std    6.407087e+05  2.217967e+06  2.034348e+05  2.253682e+06  2.204276e+06
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 75%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# max    1.104063e+08  1.191926e+08  6.573080e+07  1.191926e+08  1.191926e+08
#
# [8 rows x 67 columns]        Flow Duration  Total Fwd Packet  Total Bwd packets  \
# count   8.958300e+04      89583.000000       89583.000000
# mean    6.053160e+05         22.647489          27.567998
# std     4.873278e+06        124.888525         122.995800
# min     1.000000e+00          1.000000           0.000000
# 25%     3.490000e+02          1.000000           2.000000
# 50%     5.812000e+03          3.000000           2.000000
# 75%     1.842315e+05         17.000000          15.000000
# max     1.199920e+08      20038.000000       10979.000000
#
#        Total Length of Fwd Packet  Total Length of Bwd Packet  \
# count                8.958300e+04                8.958300e+04
# mean                 4.699256e+03                2.211271e+04
# std                  1.473890e+05                1.560744e+05
# min                  0.000000e+00                0.000000e+00
# 25%                  0.000000e+00                0.000000e+00
# 50%                  9.000000e+01                1.060000e+02
# 75%                  4.860000e+02                1.512000e+03
# max                  2.605270e+07                1.421574e+07
#
#        Fwd Packet Length Max  Fwd Packet Length Min  Fwd Packet Length Mean  \
# count           89583.000000           89583.000000            89583.000000
# mean              173.987699              14.753078               71.318198
# std               351.735761              70.655440              185.023053
# min                 0.000000               0.000000                0.000000
# 25%                 0.000000               0.000000                0.000000
# 50%                45.000000               0.000000                9.346154
# 75%               163.000000               0.000000               50.000000
# max              1476.000000            1472.000000             1474.000000
#
#        Fwd Packet Length Std  Bwd Packet Length Max  ...  Fwd Act Data Pkts  \
# count           89583.000000           89583.000000  ...       89583.000000
# mean               64.038975             365.986046  ...           8.576203
# std               156.450808             556.405437  ...         115.002022
# min                 0.000000               0.000000  ...           0.000000
# 25%                 0.000000               0.000000  ...           0.000000
# 50%                 0.000000              48.000000  ...           1.000000
# 75%                29.277002             737.000000  ...          10.000000
# max               776.150206            1460.000000  ...       20032.000000
#
#        Fwd Seg Size Min   Active Mean    Active Std    Active Max  \
# count      89583.000000  8.958300e+04  8.958300e+04  8.958300e+04
# mean          25.959166  1.779093e+04  8.236986e+03  2.837752e+04
# std            8.991518  7.342688e+05  4.735419e+05  1.084372e+06
# min            8.000000  0.000000e+00  0.000000e+00  0.000000e+00
# 25%           20.000000  0.000000e+00  0.000000e+00  0.000000e+00
# 50%           32.000000  0.000000e+00  0.000000e+00  0.000000e+00
# 75%           32.000000  0.000000e+00  0.000000e+00  0.000000e+00
# max           40.000000  9.194718e+07  6.759798e+07  1.003274e+08
#
#          Active Min     Idle Mean      Idle Std      Idle Max      Idle Min
# count  8.958300e+04  8.958300e+04  8.958300e+04  8.958300e+04  8.958300e+04
# mean   1.228748e+04  9.909433e+04  4.018908e+03  1.034929e+05  9.572188e+04
# std    6.360789e+05  2.242070e+06  2.772174e+05  2.289993e+06  2.219529e+06
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 75%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# max    9.194718e+07  1.185642e+08  7.214360e+07  1.185642e+08  1.185642e+08
#
# [8 rows x 67 columns] count    358332.000000
# mean          1.006924
# std           2.096662
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           9.000000
# Name: Label, dtype: float64 count    89583.000000
# mean         1.001451
# std          2.088613
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          9.000000
# Name: Label, dtype: float64

# %%
under_sampler = RandomUnderSampler(sampling_strategy={0: 40000}, random_state=42)  # Undersample Class 0 to 20,000 samples
smote = SMOTE(sampling_strategy={2: 3000,1:2000,7: 14000, 8: 3000,9:3000}, random_state=42)  # Oversample Classes 2, 7, and 8

# %%
X_train_resampled, y_train_resampled = under_sampler.fit_resample(X_train, y_train)

# %%
X_train_final, y_train_final = smote.fit_resample(X_train_resampled, y_train_resampled)

# %%
print("New class distribution:")
print(pd.Series(y_train_final).value_counts())
# Out:
# New class distribution:
# Label
# 0    40000
# 4    24692
# 5    23764
# 7    14000
# 6     3765
# 3     3551
# 2     3000
# 8     3000
# 9     3000
# 1     2000
# Name: count, dtype: int64

# %%
scaler = StandardScaler()
X_train_final_scaled = scaler.fit_transform(X_train_final)

# %%
X_test_scaled = scaler.transform(X_test)

# %%
pca_95 = PCA(n_components=0.95) 
X_train_final_pca_95 = pca_95.fit_transform(X_train_final_scaled)
X_test_pca_95 = pca_95.transform(X_test_scaled)

# %%
rf_classifier = RandomForestClassifier(random_state=42)
rf_classifier.fit(X_train_final_pca_95, y_train_final)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = rf_classifier.predict(X_test_pca_95)

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f"\nRandom Forest Accuracy after Resampling: {accuracy:.4f}")

print("\nClassification Report:")
report = classification_report(y_test, y_pred, target_names=[f"Class {i}" for i in np.unique(y_test)])
print(report)
# Out:
# Random Forest Accuracy after Resampling: 0.9193
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Class 0       1.00      0.98      0.99     71701
#      Class 1       0.19      0.59      0.29        68
#      Class 2       0.27      0.45      0.34       104
#      Class 3       0.38      0.17      0.24       916
#      Class 4       0.69      0.75      0.72      6259
#      Class 5       0.62      0.77      0.69      5849
#      Class 6       0.74      0.56      0.64       867
#      Class 7       0.68      0.69      0.68      3392
#      Class 8       0.27      0.26      0.27       381
#      Class 9       0.09      0.33      0.14        46
#
#     accuracy                           0.92     89583
#    macro avg       0.49      0.56      0.50     89583
# weighted avg       0.93      0.92      0.92     89583
